# %%
import random
def compare():
    num1=random.randint(1,20)
    num2=eval(input("enter a number between 1 to 20:"))
    if num1==num2:
        print("you won")
    else:
        print("you lost because the random number is{}".format(num1))
        
compare()
# Out:
# enter a number between 1 to 20:7
# you lost because the random number is17

# %%
def bill(bill_amt,tip_amt):
    try:
        total_bill=bill_amt+tip_amt
        print("total bill is {}".format(total_bill))
    except Exception as error:
        print(error)
bill(1000,500)
# Out:
# total bill is 1500

# %%
# wap ask the user enter number
# and find the squre of the number
# M-1: write in normal ways
# M-2: write in function with out argument
# M-3: write in function with argument

# %%
def squre():
    number=eval(input("enter a number"))
    print("the squre of {} is {}".format(number,number*number))
squre()
# Out:
# enter a number7
# the squre of 7 is 49

# %%
# wap ask the user
# get one random number between 1 to 20
# enter a number
# compare these two number 
# if both are same : print("you won")
# else : print(lost)

# %%
import random
num1=random.randint(1,20)
num2=eval(input("enter a number between 1 to 20:"))
if num1==num2:
    print("you won")
else:
    print("you lost")
# Out:
# enter a number between 1 to 20:7
# you lost

# %%
import random
def compare(num1,num2):

    if num1==num2:
        print("you won")
    else:
        print("you lost because the random number is{}".format(num1))
value_random=random.randint(1,20)
value=eval(input("enter number"))
compare(value_random,value)
# Out:
# enter number7
# you lost because the random number is10

# %%
import random
value_random=random.randint(1,20)
value=eval(input("enter number"))
def compare(num1,num2):
    
    if num1==num2:
        print("you won")
    else:
        print("you lost because the random number is{}".format(num1))

compare(value_random,value)
# Out:
# enter number8
# you lost because the random number is14

# %%
import random
def compare(num1,num2):
    
    if num1==num2:
        print("you won")
    else:
        print("you lost because the random number is{}".format(num1))
compare(random.randint(1,20),eval(input("enter number")))
# Out:
# enter number6
# you lost because the random number is19

# %%
# wap ask the user enter salary
# ask the user enter the tex percentage
# calculate total tax pay

# %%
salary=eval(input("enter the salary :"))
tax=eval(input("enter the tax percentage :"))               # method ------------1
tax_pay=(salary*tax)/100
print("you have to {}".format(tax_pay))
# Out:
# enter the salary :30000
# enter the tax percentage :15
# you have to 4500.0

# %%
def tax_calculate():
    salary=eval(input("enter the salary :"))
    tax=eval(input("enter the tax percentage :"))            # method ------------2
    tax_pay=(salary*tax)/100
    print("you have to {}".format(tax_pay))
tax_calculate()
# Out:
# enter the salary :30000
# enter the tax percentage :15
# you have to 4500.0

# %%
def tax_calculate(salary,tax):
    tax_pay=(salary*tax)/100
    print("you have to {}".format(tax_pay))                # method ---------------3
tax_calculate(eval(input("enter the salary :")),eval(input("enter the tax percentage :")))
# Out:
# enter the salary :50000
# enter the tax percentage :12
# you have to 6000.0

# %%
# tax percentage is always =20
# fixed
# defult parameter

# %%
def tax_cal(salary,tax_per=20):
    total_tax=salary*tax_per/100
    print("the total tax is :",total_tax)
tax_cal(salary,tax_per)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2     total_tax=salary*tax_per/100
#       3     print("the total tax is :",total_tax)
# ----> 4 tax_cal(salary,tax_per)
#
# NameError: name 'salary' is not defined

# %%
def avg(num1,num2,num3=50):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    add=(num1+num2+num3)
    avg=add/3
    print("the avg is :",avg)
avg(20,30,50)
# Out:
# num1: 20
# num2: 30
# num3: 50
# the avg is : 33.333333333333336

# %%
num1,num2,num3=100
print(num1,num2,num3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 num1,num2,num3=100
#       2 print(num1,num2,num3)
#
# TypeError: cannot unpack non-iterable int object

# %%
num1,num2,num3=100,40,50
print(num1,num2,num3)
# Out:
# 100 40 50

# %%
def avg(num1,num2,num3=500):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    add=(num1+num2+num3)
    avg=add/3
    print("the avg is :",avg)
avg(200,300)
# Out:
# num1: 200
# num2: 300
# num3: 500
# the avg is : 333.3333333333333

# %%
def avg(num1,num2,num3=500):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    num3=800
    add=(num1+num2+num3)
    avg=add/3
    print("the avg is :",avg)
avg(200,300,800)
# Out:
# num1: 200
# num2: 300
# num3: 800
# the avg is : 433.3333333333333

# %% [markdown]
# - with arguments
# - without arguments
# - default arguments

# %%
import random
random.randint()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 import random
# ----> 2 random.randint()
#
# TypeError: Random.randint() missing 2 required positional arguments: 'a' and 'b'

# %%
complex()    # not provide : defult
# Out:
# 0j

# %%
complex(5,10)
# Out:
# (5+10j)

# %%
def summ(a=0,b=0):
    print(a*b)
summ(5,10)
# Out:
# 50

# %% [markdown]
# # Bianry

# %%
v1=0b10110           # only-----------------1 and 0 use
v1
# Out:
# 22

# %% [markdown]
# # Octa

# %%
v1=0o234562          # only---------------01234567
v1
# Out:
# 80242

# %% [markdown]
# # Hexa

# %%
v1=0x23450bcf         # only--------------0123456789abcdef
v1
# Out:
# 591727567

# %%
v1=0b10010
v1
# Out:
# 18

# %%
# wap ask the user to find the circle

# %%
import math
def area(radius):
    radius=eval(input("enter the radius of circle:"))
    area=round((math.pi)*radius*radius,)
    print("the area of the circle is",area)
area(6)
# Out:
# enter the radius of circle:8
# the area of the circle is 201

# %%
import math
def area(radius=6):
    radius=eval(input("enter the radius of circle:"))
    area=round((math.pi)*radius*radius,)
    print("the area of the circle is",area)
radius=6    
area(radius)
# Out:
# enter the radius of circle:9
# the area of the circle is 254

# %%
import math
def area(radius):
    try:
        area=round((math.pi)*radius*radius,)
        print("the area of circle is",area)
    except Exception as error:
        print(error)
area(7)
# Out:
# the area of circle is 154

# %%
import math
def area(radius):
    try:
        area=round((math.pi)*radius*radius,)
        print("the area of the circle is",area)
    except Exception as error:
        print(error)

radius=eval(input("enter the radius of circle:"))
area(radius)  


#keybord funtion
# Out:
# enter the radius of circle:7
# the area of the circle is 154

# %%
area11
# function is calculating area value
# but not providing (ruturn) that value to you
# when you  want  use that value outside the function=====>error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 area11
#
# NameError: name 'area11' is not defined

# %% [markdown]
# # Return Concept

# %%
import math
def area():
    pii=math.pi
    radius=eval(input("enter the radius of circle:"))
    area=round((math.pi)*radius*radius,)
    print("the area of the circle is",area)
    return(area,pii)
Area,pi=area()
print(Area)
print(pi)
# Out:
# enter the radius of circle:20
# the area of the circle is 1257
# 1257
# 3.141592653589793

# %%
Area,pi=area()

# area() will return two values
# area,pi
#

# %%
# ask the user enter 3 number
# find the sum and average
# Return the average value and sum both

# %%
def return_the_value():
    num1=eval(input("number 1:"))
    num2=eval(input("number 2:"))
    num3=eval(input("number 3:"))
    sum1=num1+num2+num3
    avg=(sum1)/3
    return(sum1,avg)
total,avg=return_the_value()
print(total)
print(avg)
# Out:
# number 1:20
# number 2:30
# number 3:40
# 90
# 30.0

# %%
def sum_avg(n1,n2,n3):
    summ=n1+n2+n3
    avg=summ/3
    print('sum:',summ)
    print('avg:',avg)
    return(summ,avg)
addition,average=sum_avg(30,40,40)
# Out:
# sum: 110
# avg: 36.666666666666664

# %%
# find the bigest number of 3 numbers
# take three numbers
# and find the bigest number
# and return that number

# %%
num1=eval(input("enter a value of n1:"))
num2=eval(input("enter a value of n2:"))
num3=eval(input("enter a value of n3:"))
if num1>num2 and num1>num3 :
    print('{} is grater'.format(num1))
elif num2>num3:
    print('{} is grater'.format(num2))
greater()

# %%
def greater():
    num1=eval(input("enter a value of n1:"))
    num2=eval(input("enter a value of n2:"))
    num3=eval(input("enter a value of n3:"))
    if num1>num2 and num1>num3 :
        print('{} is grater'.format(num1))
    elif num2>num3:
        print('{} is grater'.format(num2))
    else:
        print('{} is grater'.format(num3))
greater()
# Out:
# enter a value of n1:20
# enter a value of n2:30
# enter a value of n3:40
# 40 is grater

# %%
def grater(num1,num2,num3):
    if num1>num2 and num1>num3 :
            print('num1 is grater')
            return(num1)
    elif num2>num3:
            print('num2 is grater')
            return(num2)
    else:
            print('num3 is grater')
            return(num3)
Grater=greater(100,200,300)
# Out:
# enter a value of n1:45
# enter a value of n2:78
# enter a value of n3:67
# 78 is grater

# %%
def add(a,b):
    return(a+b)

def mul(a,b):
    return(a*b)

def sub(a,b):
    return(a-b)

def div(a,b):
    return(a/b)
val_add=add(20,30)
val_mul=mul(20,30)
val_sub=sub(20,30)
val_div=div(20,30)
print(val_add,val_mul,val_sub,round(val_div,2))
# Out:
# 50 600 -10 0.67

# %%
def aggregation(a,b):
    return(a+b,a*b,a-b,a/b)
add,sub,mul,div=aggregation(20,30)
print(add,mul,sub,round(div,2))
# Out:
# 50 -10 600 0.67

# %%
def add(a,b):return(a+b)
def mul(a,b):return(a*b)
def sub(a,b):return(a-b)
def div(a,b):return(a/b)
val_add=add(20,30)
val_mul=mul(20,30)
val_sub=sub(20,30)
val_div=div(20,30)
print(val_add,val_mul,val_sub,round(val_div,2))
# Out:
# 50 600 -10 0.67

# %%
def aggregation(a,b):
    return(a+b,a*b,a-b,a/b)
value=aggregation(20,30)
print(value)
# Out:
# (50, 600, -10, 0.6666666666666666)

# %% [markdown]
# - With out argument
# - With argument
# - defult Arguement
# - return function

# %% [markdown]
# # Local variables

# %% [markdown]
# *Local variables**
# - The variables provided inside the function
# *Global variables**
# - The variables provide outside the function

# %%
def addition():
    n1=10
    n2=20
    add=n1+n2
    print=("the addition of {} and {} is {}".format(n1,n2,add))
addition()

# %% [markdown]
# # Global variables

# %%
    n1=10
    n2=20
def addition():    

    add=n1+n2
    print=("the addition of {} and {} is {}".format(n1,n2,add))
addition()
# Out:
#   Cell In[7], line 5
#     add=n1+n2
#     ^
# IndentationError: expected an indented block after function definition on line 3

# %% [markdown]
# - local variable are inside the function
# - local variable values can not use outside the function
# - untill unless you return those value

# %%
n1=10
n2=20
def addition():    
    n1=100
    n2=300
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
addition()
print(n1)
# Out:
# the addition of 100 and 300 is 400
# 10

# %%
n1=10
n2=20
def addition(n1):    
    n2=300
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
addition(500)     # 800
print(n1)         # 10
# Out:
# the addition of 500 and 300 is 800
# 10

# %%
n1=10
n2=20
def addition(n1=700):    
    n2=300
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
addition(500)
print(n1)
# Out:
# the addition of 500 and 300 is 800
# 10

# %%
# we can not use local variables values outside the function
# untill unless with out return statement
# i want to use local variable outside the function ,without using return statement

# %%
global

# %%
n1=10
def upadted():
    n1=n1+100
    print("n1 value inside the function is:",n1)
upadted()  # 110
print(n1) # 10

# %%
def value():
    global number1,number2
    number1=10
    number2=20
    print(number1)
     
value()
print(number1)
print(number2)
# Out:
# 10
# 10
# 20

# %%
n_=10
def updated():
    global n_
    n_=20
    n_=n_+100
    print("n1 value inside the function is:",n_)
    
updated()
print(n_)
# Out:
# n1 value inside the function is: 120
# 120

# %%
n1=10
n2=20
def addition(n1): 
    global n2,add
    n2=300
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
addition(500)     # 800
print(n2)
print(add)
# Out:
# the addition of 500 and 300 is 800
# 300
# 800

# %% [markdown]
# **Function in Function**

# %%
def greet():
    print("hello")
def name():
    print("python")
greet()
name()
# Out:
# hello
# python

# %%
# step1- define greet function
# step2- define name function/()
# step3- calling name
# step4- python
# step5- calling greet()
# step6-hello

def greet():
    print("hello")
def name():
    print("python")
    greet()
name()
# Out:
# python
# hello

# %%
def greet():
    print("hello")
    name()
def name():
    print("python")
greet()
# Out:
# hello
# python

# %%
def greet():
    print("hello")
    name()
def name():
    print("python")
    greet()
greet()
print('----------')
name()
# Out:
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# ...

# %%
# type 1=================================>
def greet():
    print("hello")
def name():
    print("python")
    print("hoe do you do")
greet()
name()

# type 2==================================>
def greet():
    print("hello")
def name():
    print("python")
    greet()
name()

# type 3=================================>
def greet():
    print("hello")
    name()
def name():
    print("python")
greet()

# %%
print(3)

def fun1():
    print('hello')
    print('python')
    
print('10+10')
def fun2():
    print('3+5')
    print(3+5)
    fun1()
    print('good')
    
print(10+10) 
def fun3():
    fun1()
    fun2()
    
fun3()
# Out:
# 3
# 10+10
# 20
# hello
# python
# 3+5
# 8
# hello
# python
# good

# %%
# create four function
# def add(a+b):
# print(a+b)
# sub
# mul
# div
# you need to provide some print statement
# if you want enter 1 : addition operation willcome
# if you want enter 2 : subtract
# if you enter 3 : mul
# if you enter 4 : div
# operation =input("enter a number")

# %%
def add(a,b):
    print(a+b)
def mul(a,b):
    print(a*b)
def sub(a,b):
    print(a-b)
def div(a,b):
    print(a/b)
def main():
    
    num1=eval(input("enter a number"))
    a=eval(input("enter value of a:"))
    b=eval(input("enter value of b:"))
    if num1==1:
        add(a,b)
    elif num1==2:
        sub(a,b)
    elif num1==3:
        mul(a,b)
    elif num1==4:
        div(a,b)
        




main()
# Out:
# enter a number1
# enter value of a:10
# enter value of b:20
# 30
